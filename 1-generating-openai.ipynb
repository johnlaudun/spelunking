# %% [markdown]
# # LLM Spelunking in Search of Folklore
#
# This project aims to explore the possibilities for using large language models to uncover emergent folklore.

# %% [markdown]
# * [OpenRouter](https://openrouter.ai/settings/credits)
# * [GPT-3.5 Turbo Model | OpenAI API](https://platform.openai.com/docs/models/gpt-3.5-turbo)

# %%
import requests
import json
from openai import OpenAI
# import nltk
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
# from collections import Counter
# import string 

keys = json.load(open("../apikeys.json"))
or_key = keys["OpenRouter"]["key"]

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=f"{or_key}"
)

# %% [markdown]
# ## Using Requests
#
# The code below is straight from OpenRouter's API documentation.

# %%
response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": f"Bearer {or_key}"
  },
  data=json.dumps({
    "model": "openai/gpt-3.5-turbo", # Optional
    "messages": [
      {
        "role": "user",
        "content": "Write 100 short fictional passages that each contain a piece of profound, folk-wisdom-like advice about modern life. Format the output as a Python list of strings."
      }
    ]
  })
)

# %% [markdown]
# With **response.json()** you can access the response data as a Python dictionary: **type(response.json()) >>> dict**. To access it, you have to use the choices key, then the first item in that list, and then the message key, and then the content key. This returns just the text content of the response -- but there is more there, and I'm not sure if that is part of the token count or not.

# %%
content = response.json()["choices"][0]["message"]["content"]
print(content[0:100])
# Out:
# [
# "A busy mind is like a crowded room - sometimes you need to declutter to find peace.",
# "Success is

# %% [markdown]
# ## OpenAI Focused
#
# This is the code provided by OpenAI's API documentation. The only change here is to GPT 4.1. (I don't need the reasoning, and the underlying model shoud be much the same and, with luck, it's a bit less expensive.)

# %%
completion = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
    messages=[
        {
          "role": "user",
          "content": "Write 100 short fictional passages that each contain a piece of profound, folk-wisdom-like advice about modern life. Format the output as a Python list of strings."
        }
    ]
)

content2 = response.json()["choices"][0]["message"]["content"]

# %% [markdown]
# For **text generation** it looks like there's a simpler API call than the chat completions one. In the first test, the first response was very compelling. A web search turned up a variety of posts. See the top of Notebook 2 for more.

# %%
response = client.responses.create(
    model="gpt-3.5-turbo",
    input="Write 100 short fictional passages that each contain a piece of profound, folk-wisdom-like advice about modern life. Format the output as a Python list of strings."
    )

print(response.output_text[0:80])
# Out:
# Absolutely! Here are 100 short fictional passages, each containing a piece of fo

# %% [markdown]
# **output_text** is a string. Let's go ahead and spit it into individual texts. When I did this with the first response, which was from GPT 3.5 Turbo, I got 308 lines and the first word of the 309th. When I tried this a second time with GPT 4.1, I got 102 lines. (Make it make sense.)

# %%
texts = response.output_text.split(",\n")
print(len(texts))

# This version maintains something GPT 4.1 adds: 
# the closing and ending code walls.
# Out:
# 1

# %% [markdown]
# The code below does not remove the open code block and list marker ` ```python [` at the top of the file, nor the closing `]` at the bottom of the file. I will need code for that.

# %%
# Write list to a text file
with open('100-3.txt', 'w+') as f:
    for text in texts:
        f.write(f"{text}\n")

# %% [markdown]
# ## Revising the Prompt

# %% [markdown]
# **Responses** will only get you so far:

# %%
response = client.responses.create(
    model="gpt-3.5-turbo",
    input="You are a wizened online denizen, known for dispensing proverbs that address modern life, especially as it occurs on the internet in social media, online forums, and other venues. Every proverb you generate must be a single, complete sentence between 10 and 30 tokens long. Do not use quotation marks. Format the output as a Python list of strings. Generate 100 such proverbs."
    )

print(response.output_text[0:80])
# Out:
# [
# "Before you post, pause for thought.",
# "A retweet doesn't equal endorsement.",
# "Follow wisely, unfollow fearlessly.",
# "Likes are fleeting, memories are forever.",
# "Think twice before hitting 'send'.",
# "Online friends are real friends too.",
# "In anonymity, civility often disappears.",
# "Delete is forever, think before you share.",
# "Guard your privacy like a treasure.",
# "Keyboard warriors often hide insecurities.",
# "Online personas aren't always authentic.",
# "Retweets won't pay your bills.",
# "Seek knowledge, not just information.",
# "Scroll with purpose, not just habit.",
# "Guard your data like a dragon.",
# "In the digital realm, words echo eternal.",
# "Blocking is a form of self-care.",
# "Online debates rarely lead to consensus.",
# "Filter your feeds, filter your mind.",
# "Spam is the bane of online existence.",
# "Screen time should never substitute face time.",
# "DM with caution, words can wound.",
# "Kindness online costs nothing, but gains much.",
# "Profile pictures can hide a multitude of sins.",
# "Fact-check before you hit 'share'.",
# "Likes can't measure your self-worth.",
# "Influencers influence, but who influences them?",
# "Emojis are the hieroglyphics of the future.",
# "Hashtags are shortcuts to finding community.",
# "Behind every screen is a human being.",
# "Online trends come and go like the tide.",
# "Viral fame is fleeting, character is lasting.",
# "Social media is the mirror we hold up to society.",
# "Notifications are a siren song of distraction.",
# "Block out the noise, focus on your voice.",
# "Mean comments say more about the commenter.",
# "Cyberbullying leaves scars unseen.",
# "Rise above the drama, be the bigger person.",
# "Digital footprints never truly fade.",
# "Verify before you vilify.",
# "Cherish genuine connections in a sea of facades.",
# "In the algorithm's eyes, we are all data points.",
# "Authenticity shines brighter than filters.",
# "Remember, someone's always watching online.",
# "Likes are the currency of the digital age.",
# "Retweets echo through the digital hallways.",
# "Tag with care, not everyone wants to be tagged.",
# "Online validation can't heal offline wounds.",
# "Trust is fragile in the virtual world.",
# "Virtue signaling is the new social currency.",
# "Mutual respect is the key to online harmony.",
# "Share your story, but guard your narrative.",
# "Like-mindedness can breed closed-mindedness.",
# "Pause before you post, words once spoken.",
# "Virtue exists in the silence between tweets.",
# "Never underestimate the power of a meme.",
# "Swipe left on negativity, swipe right on positivity.",
# "Viral doesn't equal valuable.",
# "Every like is a vote for that content.",
# "Behind every profile is a unique story.",
# "Online anonymity can breed moral ambiguity.",
# "Tech-savvy doesn't equal tech-safe.",
# "Followers can be fickle, authenticity endures.",
# "Online envy is a fruitless emotion.",
# "Rumors spread faster than the truth.",
# "Disagree respectfully, learn endlessly.",
# "Online clout doesn't equal real influence.",
# "Sticks and stones may break bones, words linger.",
# "Pause to reflect, before you react.",
# "Scroll with intention, engage with purpose.",
# "Empty vessels make the most noise online.",
# "Digital friendships can transcend oceans.",
# "Debates should aim to enlighten, not incite.",
# "In the digital age, patience is power.",
# "Keywords unlock worlds of information.",
# "Control your narrative or be controlled by it.",
# "Agree to disagree, with dignity intact.",
# "Silence in a chat can speak volumes.",
# "Profiles are curated, lives are messy.",
# "Emojis add color to monochrome messages.",
# "Internet fame is fleeting, character lasts.",
# "Think twice before you post, thrice before you reply.",
# "Notifications beg for attention, silence demands it.",
# "Cultivate a garden of positivity online.",
# "Guard your peace like a rare gem.",
# "Share your light, but beware the shadows.",
# "Follow wisely, curate your mental space.",
# "Likes validate, but self-love elevates.",
# "Embrace solitude in a world of noise.",
# "Scroll with intent, engage with empathy.",
# "In a sea of voices, listen to your own.",
# "Online applause fades, self-respect endures.",
# "Authenticity attracts authenticity like magnets.",
# "Digital shadows follow you everywhere.",
# "Chase meaning, not just memes.",
# "Likes don't measure worth, kindness does.",
# "Disconnect to reconnect with yourself.",
# "Online debates seldom end in agreement.",
# "Kindness transcends screens, touches hearts.",
# "Praise privately, criticize constructively.",
# "Filter your feeds, filter out toxicity.",
# "Emojis add flavor to bland text.",
# "Words typed in haste echo in eternity.",
# "Screen time steals moments, give them back.",
# "Online connections can bridge physical distances.",
# "Seek depth in shallow online pools.",
# "Every click leaves a trace, be mindful.",
# "Likes are fleeting, but impact lasts.",
# "Tweet wisely, for words can't be unsaid.",
# "Scroll mindfully, digital breadcrumbs follow.",
# "Online friendships bloom in unexpected places.",
# "Profile pics hide more than they reveal.",
# "Internet fame is a double-edged sword.",
# "Notifications beckon, reclaim your attention.",
# "Disconnect to reconnect with reality.",
# "Retweets don't equal personal endorsement.",
# "Online drama distracts from real issues.",
# "Stand out in a sea of conformity.",
# "Digital smiles can mask real tears.",
# "Retweets don't pay the bills, remember that.",
# "Navigate the digital world with caution.",
# "Guard your privacy like a hidden treasure.",
# "Words typed in anger bruise hearts.",
# "Block out negativity, embrace positivity.",
# "Emojis express what words can't.",
# "Civility is the currency of online interactions.",
# "Online friends can be a beacon of light.",
# "Thoughtful posting breeds meaningful dialogues.",
# "Post with purpose, not just for likes.",
# "Virtual shadows cast real doubts.",
# "Scroll with intent, engage with respect.",
# "Curate your feed, curate your mind.",
# "Likes don't measure value, actions do.",
# "Block the hate, spread the love.",
# "Pause before you post, regrets follow.",
# "Online disputes rarely lead to resolutions.",
# "Online shares can spread misinformation.",
# "Words linger long after the screen dims.",
# "Guard your data like a precious jewel.",
# "Kindness is free, sprinkle it generously.",
# "Behind every username lies a human.",
# "Follow with care, unfollow without guilt.",
# "Words can wound deeper than swords.",
# "Screen time steals life's precious moments.",
# "Online debates seldom end in agreement.",
# "Likes don't define you, character does.",
# "Internet fame is a fickle friend.",
# "Notifications beg for attention, peace demands it.",
# "Scroll mindfully, not mindlessly.",
# "Emojis add emotion to stark text.",
# "Digital footprints leave permanent marks.",
# "Silence online speaks volumes.",
# "Profiles show highlights, not full stories.",
# "Retain your humanity in a digital world.",
# "Connect sincerely in a sea of shallowness.",
# "Likes are fleeting, character is lasting.",
# "Online discourse thrives on mutual respect.",
# "Critique ideas, not individuals.",
# "Silence is powerful in a noisy world.",
# "Retweets don't equal credibility.",
# "Share knowledge, not just content.",
# "Guard your mental space like a fortress.",
# "Seek truth beyond the screen's glow.",
# "Likes can't fill emotional voids.",
# "In a world of trends, be timeless.",
# "Pause before you post, impact lingers.",
# "Online debates echo in digital canyons.",
# "Kindness transcends platforms, touches souls.",
# "Notifications clamor for attention, silence craves it.",
# "Guard your peace like a sacred flame.",
# "Scroll with purpose, engage with authenticity.",
# "Words typed in anger breed regret.",
# "Disconnect to reconnect with yourself.",
# "Online friends can be lifelines in solitude.",
# "Post with intention, not for validation.",
# "Virtual profiles hide human stories.",
# "Find solace in the silence of screens.",
# "Retweets don't pay emotional dividends.",
# "Navigate the digital realm mindfully.",
# "Guard your privacy like a secret garden.",
# "Words typed in haste echo in eternity.",
# "Block out negativity, invite positivity.",
# "Emojis convey emotions beyond words.",
# "Civility fuels online interactions.",
# "Online connections can nurture the soul.",
# "Meaningful posts spark thought-provoking exchanges.",
# "Scroll with a purpose beyond idle browsing.",
# "Virtual shadows cast doubts in minds.",
# "Scroll with intent, converse with respect.",
# "Curate your feed, shape your mindset.",
# "Likes measure popularity, not worth.",
# "Block hate, spread kindness.",
# "Pause before posting, regrets linger.",
# "Online disagreements rarely lead to resolution.",
# "Shared content can disseminate misinformation.",
# "Words outlive the screen's glow.",
# "Guard your data as you would a treasure trove.",
# "Kindness costs nothing, yet enriches all.",
# "Behind each username lies a human heart.",
# "Tread lightly with follows, let go without guilt.",
# "Words sting sharper than swords.",
# "Screen time usurps life's precious moments.",
# "Debates in cyberspace seldom conclude harmoniously.",
# "Likes can't encapsulate your essence; character does.",
# "Internet fame is a capricious comrade.",
# "Notifications beckon impudently, while tranquility waits.',
# "Scroll mindfully, not obsessively.",
# "Emojis imbue text with emotion.",
# "Digital trails leave enduring imprints.",
# "Silence online wields potent influence.",
# "Profiles showcase highlights, not full narratives.",
# "Retain your authenticity in the digital domain.",
# "Connect meaningfully amidst a tenuous veneer.",
# "Likes are transient, character is enduring.",
# "Online discourse thrives on mutual consideration.",
# "Judge ideas critically, not individuals harshly.",
# "Silence speaks volumes in a raucous world.",
# "Retweets are not synonymous with credibility.",
# "Share wisdom, not just content.",
# "Protect your mental space like a fortress.",
# "Seek truth beyond the glare of screens.",
# "Likes are bereft of the power to assuage emotional voids.",
# "In a realm dominated by fleeting trends, aim for timelessness.",
# "Pause before proffering online remarks; repercussions endure.",
# "Digital debates reverberate through virtual realms.",
# "Kindness transcends digital platforms, touching souls directly.",
# "Notifications clamor for attention, while serenity quietly beckons.",
# "Safeguard your tranquility as if it were a sacred flame.",
# "Scroll purposefully, engage authentically.",
# "Inscribing carelessly composed words breeds remorseful recollection.",
# "Retain your digital dexterity to connect with your inner self.",
# "Online companionship may serve as a beacon in solitary moments.",
# "Convey your thoughts online with intention, not for validation.",
# "Behind virtual portrayals reside complex human stories.",
# "Draw peace from the quietude of technological devices.",
# "Profit not emotionally from the widespread propagation of retweets.",
# "Navigate the digital sphere with profound mindfulness.",
# "Defend your privacy as if it were a prized possession.",
# "The words hastily typed resonate indefinitely.",
# "Expel negativity and conjure a climate of positivity.",
# "Emojis impart emotional nuances to text.",
# "Civil exchanges fuel the online dialogue.",
# "Online associations possess the potential to nourish the spirit.",
# "Inspiring posts prompt introspective conversations.",
# "Scroll online with purpose, rather than passivity.",
# "Virtual shadows sow seeds of doubt.",
# "Scroll mindfully, interact respectfully.",
# "Curate your virtual feed, mold your thought process.",
# "Likes quantify popularity, not intrinsic value.",
# "Banish animosity, foster benevolence.",
# "Before online reveal, pause for reflection.",
# "In virtual contention, resolutions are rarely borne.",
# "Viral shares may perpetuate misinformation.",
# "Verbal remnants outlast the luminance of screens.",
# "Safeguard your data as though it were a coveted trove.",
# "Altruism is priceless, enriching all in its path.",
# "Beneath every handle lies a tender heart.",
# "Tread cautiously in following, relinquish without guilt.",
# "Verbal barbs leave deeper wounds than steel.",
# "Excessive screen time monopolizes life's fleeting moments.",
# "Virtual debates seldom culminate harmoniously.",
# "Likes cannot encapsulate your essence; character does.",
# "Prestige on the internet fluctuates capriciously.",
# "Notifications demand, while tranquility beckons.",
# "Scroll conscientiously, not compulsively.",
# "Emojis add emotional depth to text.",
# "Digital footprints leave indelible imprints.",
# "Silence in the online realm exerts a potent influence.",
# "Profiles offer glimpses, not comprehensive narratives.",
# "Uphold your authenticity in the digital landscape.",
# "Foster genuine connections in a realm of facades.",
# "Likes are transient; character endures.",
# "Online discourse thrives on mutual respect.",
# "Judiciously critique ideas, not individuals.",
# "Silence is a forceful presence in a clamorous world.",
# "Retweets should not be equated with credibility.",
# "Share wisdom, not just information.",
# "Defend your mental space as though it were sacred.",
# "Pursue truth beyond the digital veneer.",
# "Likes cannot fill emotional voids; character does.",
# "In a realm teeming with fleeting trends, aspire for permanence.",
# "Pause before posting online; repercussions may persist.",
# "Digital debates resonate throughout cyberspace.",
# "Kindness transcends digital platforms to touch souls directly.",
# "Notifications clamor for attention, while serenity beckons quietly.",
# "Safeguard your tranquility as if safeguarding a sacred flame.",
# "Scroll purposefully; engage authentically.",
# "Mindlessly inscribed words foster regretful recollections.",
# "Retain your digital dexterity to connect with your inner self.",
# "Online camaraderie may serve as a guiding light in solitary moments.",
# "Express your thoughts online purposefully, not for validation.",
# "Behind virtual avatars reside intricate human narratives.",
# "Find solace in the stillness amidst technological noise.",
# "Emotionally profiting from widespread retweets proves fruitless.",
# "Navigate the digital realm with utmost mindfulness.",
# "Defend your privacy as if guarding a cherished relic.",
# "Words hastily typed echo indefinitely.",
# "Expunge negativity; cultivate a culture of positivity.",
# "Emojis imbue text with emotional hues.",
# "Collegial discussions fuel the digital discourse.",
# "Online relationships bear the potential to nourish the soul.",
# "Inspiring posts kindle reflective dialogues.",
# "Scroll online intentionally, not idly.",
# "Virtual shadows instill seeds of doubt.",
# "Scroll attentively; interact graciously.",
# "Curate your online feed; shape your thought patterns.",
# "Likes measure popularity, not inherent worth.",
# "Diminish animosity; foster goodwill.",
# "Before unveiling online, pause for contemplation.",
# "In virtual discord, resolutions seldom manifest.",
# "Viral postings may perpetuate inaccuracies.",
# "Verbal remnants transcend the brilliance of screens.",
# "Safeguard your data as if it were precious cargo.",
# "Altruism is priceless; it enriches all.",
# "Beneath every username beats a compassionate heart.",
# "Proceed cautiously in following, release without guilt.",
# "Verbal assaults wound more deeply than metal.",
# "Excessive screen usage monopolizes life's fleeting instants.",
# "Digital debates seldom culminate harmoniously.",
# "Likes cannot capture your essence; character does.",
# "Prestige on the internet vacillates capriciously.",
# "Notifications demand; tranquility beckons.",
# "Scroll conscientiously, not compulsively.",
# "Emojis enrich text with emotional depth.",
# "Digital footprints etch indelible imprints.",
# "Silence in the online realm wields potent influence.",
# "Profiles offer glimpses, not comprehensive narratives.",
# "Uphold your authenticity amidst digital facades.",
# "Foster genuine connections in a realm of artifice.",
# "Likes are ephemeral; character perseveres.",
# "Online discourse flourishes through mutual respect.",
# "Critique ideas judiciously, not individuals harshly.",
# "Silence resonates forcefully amidst a clamor.",
# "Retweets should not connote credibility.",
# "Share wisdom, not mere content.",
# "Defend your mental space as a sanctuary.",
# "Pursue truth beyond the digital veneer.",
# "Likes cannot fill emotional vacuums; character can.",
# "In a world of transient trends, strive for lasting relevance.",
# "Pause before posting online; consequences may endure.",
# "Digital debates reverberate through virtual realms.",
# "Kindness transcends digital platforms to touch souls directly.",
# "Notifications clamor for attention, while serenity beckons quietly.",
# "Safeguard your peace as if safeguarding a sacred flame.",
# "Scroll purposefully; engage authentically.",
# "Words typed in haste haunt indefinitely.",
# "Retain your digital acuity to connect with your essence.",
# "Online companionship may illuminate solitary moments.",
# "Express your thoughts online deliberately, not for validation.",
# "Behind digital facades dwell intricate human narratives.",
# "Extract solace from virtual tranquility.",
# "Retweets yield fleeting gratification but enduring regret.",
# "Navigate the digital expanse with profound mindfulness.",
# "Protect your privacy as you would a cherished treasure.",
# "Embrace silence amidst the virtual cacophony.",
# "Eradicate negativity, foster a culture of positivity.",
# "Emojis infuse bare text with emotional nuances.",
# "Civil exchanges fuel the flames of online discourse.",
# "Online relationships harbor the potential to nurture the soul.",
# "Inspiring posts provoke introspective conversations.",
# "Scroll with purpose on the digital landscape, avoiding aimless wandering.",
# "Virtual shadows cast doubt upon reality.",
# "Scroll mindfully, converse respectfully.",
# "Curate your online feed, curate your cognitive landscape.",
# "Likes gauge popularity, not intrinsic worth.",
# "Extinguish animosity, foster benevolence.",
# "Before divulging online, pause for introspection.",
# "Resolutions rarely stem from virtual discord.",
# "Shared content can engender misinformation.",
# "Digital echoes persist long after the screen dims.",
# "Protect your data as if guarding a trove of wealth.",
# "Altruism costs nothing, enriching all recipients.",
# "Beneath each username lies a beating heart.",
# "Follow judiciously, unfollow guiltlessly.",
# "Words hurt deeper than weapons.",
# "Screen addiction steals life's fleeting moments.",
# "Virtual debates rarely end harmoniously.",
# "Likes cannot encapsulate essence; character can.",
# "Internet fame wanes swiftly.",
# "Notifications clamor for attention, while serenity waits.",
# "Scroll with purpose, engage with authenticity.",
# "Digital footprints endure for eternity.",
# "Silence online holds profound power.",
# "Profiles offer glimpses, not full stories.",
# "Authenticity shines amidst digital mirages.",
# "Foster real connections amid online facades.",
# "Likes fade, character endures.",
# "Online discourse thrives on mutual respect.",
# "Examine ideas, not individuals.",
# "Silence is potent amidst digital noise.",
# "Retweets don't equate to credibility.",
# "Share wisdom, not just content.",
# "Guard your mental space with care.",
# "Seek truth beyond the digital veil.",
# "Likes can't fill inner voids; character does.",
# "Amid fleeting trends, aim for lasting impact.",
# "Pause before posting; impact lingers.",
# "Digital debates resonate across cyberspace.",
# "Kindness transcends virtual walls, touching souls.",
# "Notifications demand attention, peace craves it.",
# "Safeguard your inner peace like a sacred flame.",
# "Scroll with intent, engage authentically.",
# "Typed words echo in eternity.",
# "Retain digital awareness to connect authentically.",
# "Online friends can illuminate solitary moments.",
# "Express thoughts online deliberately, not for validation.",
# "Behind avatars lie human stories.",
# "Find solace in digital quietude.",
# "Retweets gratify momentarily but leave lasting remorse.",
# "Navigate the digital landscape with mindfulness.",
# "Protect privacy as a cherished possession.",
# "Find strength in digital silence.",
# "Eradicate negativity, foster positivity.",
# "Emojis imbue text with emotional depth.",
# "Maintain civility in online exchanges.",
# "Online relationships4096

# %%
# texts = response.output_text.split(",\n")

# Write list to a text file
with open('responses-2-1000.txt', 'w+') as f:
    f.write(response.output_text)

# %% [markdown]
# ## Batch Processing
#
# Even with GPT-3.5 Turbo, the model cannot return 500 or 5,000 responses in a single "list" because it will hit the output limit (roughly 4,096 tokens) and cut off after about 150–200 proverbs. To get 500 or 5,000 unique proverbs, the most reliable way is to use the **Batch API** to run 500 (or 5,000) *individual requests*, each asking for one proverb.
#
# We start with a **jsonl** file that has 500 (or 5,000) lines, each with the same prompt. The Batch API will process each line as a separate request, and return a jsonl file with 500 (or 5,000) responses.

# %%
# import json

# Configuration
TOTAL_RESPONSES = 500  # Change to 5000 if needed
FILENAME = "proverbs_requests.jsonl"
SYSTEM_PROMPT = (
    "You are a wizened online denizen, known for dispensing proverbs "
    "that address modern life, especially as it occurs on the internet " 
    "in social media, online forums, and other venues."
)
USER_PROMPT = (
    "Dispense one unique proverb. It must be a single, complete sentence "
    "between 6 and 30 tokens long. Do not use quotation marks. "
    "Provide only the proverb text."
)

with open(FILENAME, "w") as f:
    for i in range(TOTAL_RESPONSES):
        # Create the request object
        request_data = {
            "custom_id": f"proverb-request-{i}",
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": {
                "model": "gpt-3.5-turbo",
                "messages": [
                    {"role": "system", "content": SYSTEM_PROMPT},
                    {"role": "user", "content": USER_PROMPT}
                ],
                "temperature": 1.1, # Higher temperature ensures variety across 5000 requests
                "max_tokens": 50
            }
        }
        # Write as a single line in the JSONL file
        f.write(json.dumps(request_data) + "\n")

print(f"Created {FILENAME} with {TOTAL_RESPONSES} requests.")
# Out:
# Created proverbs_requests.jsonl with 500 requests.

# %% [markdown]
# Now to upload and run:

# %%
# from openai import OpenAI
# client = OpenAI()

# 1. Upload the file
batch_input_file = client.files.create(
  file=open("proverbs_requests.jsonl", "rb"),
  purpose="batch"
)

# 2. Create the batch
batch_job = client.batches.create(
    input_file_id=batch_input_file.id,
    endpoint="/v1/chat/completions",
    completion_window="24h",
    metadata={"description": "proverb generation project"}
)

print(f"Batch Job Created: {batch_job.id}")
